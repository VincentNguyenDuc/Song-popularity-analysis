# %%
import os
import sys

current_path = os.getcwd()
data_path = current_path.replace('src', 'data')

# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 7.5]

# %%
# import data
song_data = pd.DataFrame(pd.read_csv(data_path + '\\raw\\song_data.csv'))
song_data
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams                4            262333
# 1                      In The End                4            216933
# 2               Seven Nation Army                4            231733
# 3                      By The Way                4            216933
# 4               How You Remind Me                3            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe                3            159645
# 18831                     Answers                3            205666
# 18832      Sudden Love (Acoustic)                2            182211
# 18833           Gentle on My Mind                3            352280
# 18834                    Up to Me                3            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# ...

# %%
# choosing features
song_data.corr()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20612\993346198.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   song_data.corr()
#                   song_popularity  song_duration_ms  acousticness  \
# song_popularity          1.000000         -0.020966     -0.065793
# song_duration_ms        -0.020966          1.000000     -0.097882
# acousticness            -0.065793         -0.097882      1.000000
# danceability             0.104594         -0.104985     -0.182500
# energy                   0.001822          0.092688     -0.662639
# instrumentalness        -0.128550         -0.015188      0.173098
# key                     -0.007539         -0.004615     -0.002025
# liveness                -0.038321          0.016086     -0.082537
# loudness                 0.100378          0.016469     -0.557744
# ...

# %%
# divide the data set randomly into a 75% training set and a 25% testing set
features = song_data.iloc[:, 2:]
popularity = song_data.iloc[:, 1]
features_train, features_test, popularity_train, popularity_test = train_test_split(features, popularity, test_size=0.25, random_state=0)

# %%
# write testing data to csv
pd.DataFrame(features_test).to_csv(data_path + '\\testing\\features_test.csv', index=False)
pd.DataFrame(popularity_test).to_csv(data_path + '\\testing\\popularity_test.csv', index=False)

# %%
# write training data to csv
pd.DataFrame(features_train).to_csv(data_path + '\\training\\features_train.csv', index=False)
pd.DataFrame(popularity_train).to_csv(data_path + '\\training\\popularity_train.csv', index=False)
